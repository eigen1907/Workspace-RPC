# %%
import os, sys
sys.path.append("/users/hep/eigen1907/Workspace/Workspace-RPC/modules")
from pathlib import Path
from NanoAODTnP.Plotting.PlotDetectorMap import plot_detector_map

# %%
store_path = Path('/users/hep/eigen1907/store/TnP-NanoAOD/analysis')
cond_path = Path('/users/hep/eigen1907/store/TnP-NanoAOD/condition')
output_path = Path('/users/hep/eigen1907/Workspace/Workspace-RPC/240425-TnP_RPC24/plotting/map_eff_by_det')

data_type_list = ['without_blacklist', 'with_blacklist_roll', 'with_blacklist_roll_run']

value_list = ['efficiency', 'denominator', 'numerator']
data_era_list = ['Run2022', 'Run2023']
data_label_list = ['2022', '2023']
lumi_list = [34.7, 27.9]

for value in value_list:
    for data_type in data_type_list:
        for idx in range(len(data_era_list)):
            plot_detector_map(
                input_path = store_path / data_type / f'{data_era_list[idx]}.root',
                geom_path = cond_path / 'geometry' / 'run3.csv',
                output_dir = output_path / value / data_type / data_era_list[idx],
                roll_blacklist_path = '/users/hep/eigen1907/store/TnP-NanoAOD/condition/blacklist/roll-blacklist.json',
                com = 13.6,
                year = data_label_list[idx],
                lumi = lumi_list[idx],
                label = 'Work in Progress',
                value = value,
            )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 15
#      13 for data_type in data_type_list:
#      14     for idx in range(len(data_era_list)):
# ---> 15         plot_detector_map(
#      16             input_path = store_path / data_type / f'{data_era_list[idx]}.root',
#      17             geom_path = cond_path / 'geometry' / 'run3.csv',
#      18             output_dir = output_path / value / data_type / data_era_list[idx],
#      19             roll_blacklist_path = '/users/hep/eigen1907/store/TnP-NanoAOD/condition/blacklist/roll-blacklist.json',
#      20             com = 13.6,
#      21             year = data_label_list[idx],
#      22             lumi = lumi_list[idx],
#      23             label = 'Work in Progress',
#      24             value = value,
#      25         )
#
# File ~/Workspace/Workspace-RPC/modules/NanoAODTnP/Plotting/PlotDetectorMap.py:188, in plot_detector_map(input_path, geom_path, output_dir, com, year, lumi, label, value, percentage, roll_blacklist_path)
#     177 def plot_detector_map(input_path: Path,
#     178                       geom_path: Path,
#     179                       output_dir: Path,
#    (...)
#     186                       roll_blacklist_path: Optional[Path] = None,
#     187 ):
# --> 188     input_file = uproot.open(input_path)
#     190     if roll_blacklist_path is None:
#     191         roll_blacklist = set()
#
# File ~/micromamba/envs/pyroot/lib/python3.12/site-packages/uproot/reading.py:142, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     133 if not isinstance(file_path, str) and not (
#     134     hasattr(file_path, "read") and hasattr(file_path, "seek")
#     135 ):
#     136     raise ValueError(
#     137         "'path' must be a string, pathlib.Path, an object with 'read' and "
#     138         "'seek' methods, or a length-1 dict of {file_path: object_path}, "
#     139         f"not {path!r}"
#     140     )
# --> 142 file = ReadOnlyFile(
#     143     file_path,
#     144     object_cache=object_cache,
#     145     array_cache=array_cache,
#     146     custom_classes=custom_classes,
#     147     decompression_executor=decompression_executor,
#     148     interpretation_executor=interpretation_executor,
#     149     **options,
#     150 )
#     152 if object_path is None:
#     153     return file.root_directory
#
# File ~/micromamba/envs/pyroot/lib/python3.12/site-packages/uproot/reading.py:561, in ReadOnlyFile.__init__(self, file_path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     556 self.hook_before_create_source()
#     558 source_cls, file_path = uproot._util.file_path_to_source_class(
#     559     file_path, self._options
#     560 )
# --> 561 self._source = source_cls(file_path, **self._options)
#     563 self.hook_before_get_chunks()
#     565 if self._options["begin_chunk_size"] < _file_header_fields_big.size:
#
# File ~/micromamba/envs/pyroot/lib/python3.12/site-packages/uproot/source/fsspec.py:55, in FSSpecSource.__init__(self, file_path, **options)
#      52 self._file = None
#      53 self._fh = None
# ---> 55 self._open()
#      57 self.__enter__()
#
# File ~/micromamba/envs/pyroot/lib/python3.12/site-packages/uproot/source/fsspec.py:69, in FSSpecSource._open(self)
#      67 def _open(self):
#      68     self._executor = FSSpecLoopExecutor()
# ---> 69     self._file = self._fs.open(self._file_path)
#
# File ~/micromamba/envs/pyroot/lib/python3.12/site-packages/fsspec/spec.py:1303, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1301 else:
#    1302     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1303     f = self._open(
#    1304         path,
#    1305         mode=mode,
#    1306         block_size=block_size,
#    1307         autocommit=ac,
#    1308         cache_options=cache_options,
#    1309         **kwargs,
#    1310     )
#    1311     if compression is not None:
#    1312         from fsspec.compression import compr
#
# File ~/micromamba/envs/pyroot/lib/python3.12/site-packages/fsspec/implementations/local.py:191, in LocalFileSystem._open(self, path, mode, block_size, **kwargs)
#     189 if self.auto_mkdir and "w" in mode:
#     190     self.makedirs(self._parent(path), exist_ok=True)
# --> 191 return LocalFileOpener(path, mode, fs=self, **kwargs)
#
# File ~/micromamba/envs/pyroot/lib/python3.12/site-packages/fsspec/implementations/local.py:355, in LocalFileOpener.__init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     353 self.compression = get_compression(path, compression)
#     354 self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 355 self._open()
#
# File ~/micromamba/envs/pyroot/lib/python3.12/site-packages/fsspec/implementations/local.py:360, in LocalFileOpener._open(self)
#     358 if self.f is None or self.f.closed:
#     359     if self.autocommit or "w" not in self.mode:
# --> 360         self.f = open(self.path, mode=self.mode)
#     361         if self.compression:
#     362             compress = compr[self.compression]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/users/hep/eigen1907/store/TnP-NanoAOD/analysis/without_blacklist/Run2022.root'
